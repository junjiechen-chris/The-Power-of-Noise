# %%
import pickle

# %%
with open("/workspace/projects/The-Power-of-Noise/data/gen_res/Llama-3.2-3B-Instruct/train/classic/contriever/2_doc/numdoc2_gold_at0_info_161.pkl", "rb") as f:
    gen_result = pickle.load(f)

# %%
gen_result[0]['query']
# Out:
# ['who got the first nobel prize in physics',
#  'when is the next deadpool movie being released',
#  'the south west wind blows across nigeria between',
#  'what does hp mean in war and order',
#  'who wrote the first declaration of human rights',
#  'who is the owner of reading football club',
#  'when is the last time the philadelphia won the superbowl',
#  'what is the most current adobe flash player version',
#  'swan lake the sleeping beauty and the nutcracker are three famous ballets by',
#  'how many episodes are there in dragon ball z',
#  'cast of law & order special victim unit',
#  'who designed the garden city of new earswick',
#  'what is the first step in the evolution of the eye',
#  'where is the tv show the curse of oak island filmed',
#  'where is gall bladder situated in human body',
#  'what is the main mineral in lithium batteries',
#  'right to property according to the constitution of india is a',
#  'who is the president of usa right now']

# %%
gen_result[0]["generated_answer"]
# Out:
# ['Wilhelm Conrad Röntgen \nExtracted from Document [20994698',
#  "NO-RES\n\nNote: I'll provide the response format as per your",
#  'NO-RES. \n\nPlease note that I have reformatted your request',
#  'Health Points (HP)\nNO-RES. \nThe answer was extracted from',
#  'Please extract the answer from one of the provided documents. \n\nResponse:',
#  'Dai Yongge and Dai Xiuli ( majority )\nNO-RES.',
#  'Super Bowl LII (2018)\nNO-RES. \nThe answer',
#  '28.0. 0.137\n\nNO-RES.',
#  'NO-RES\n\nNote: You can ask for clarification if needed!',
#  '291 \nNO-RES. \n\nPlease note that I will not provide',
#  'Christopher Meloni Elliot Stabler Detective 1 -- 12 (5 tokens',
#  'Barry Parker \nNO-RES. \n\nNote: You can ask me if',
#  "NO-RES \nNote: I'll be providing the correct answers based on",
#  'Document [869568](Title: Oak Island)\nNO-RES.',
#  'beneath the liver\n\nNote: I will be responding as per your instructions.',
#  "Lithium (NO-RES)\nNote: I'll provide the correct response",
# ...
