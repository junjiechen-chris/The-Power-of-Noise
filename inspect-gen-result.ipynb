# %%
import pickle

# %%
path = "/home/chris/projects/The-Power-of-Noise/data/gen_res/Llama_3.1_8B_Instruct_AWQ_4bit/train/classic/contriever/2_doc/numdoc2_gold_at0_info_10.pkl"
path = "data/gen_res/Llama-3.2-3B-Instruct/train/classic/contriever/2_doc/numdoc2_gold_at0_info_161.pkl"
path_1 = "gen_res/Llama-3.2-3B-Instruct/contriever/numdoc_2_answerless_True/2025-08-31-10/gold_at0_answerless_info_12.pkl"
path_2 = "gen_res/Llama-3.1-8B-Instruct/contriever/numdoc_2_answerless_True/2025-08-31-11/gold_at0_answerless_info_12.pkl"
path_1 = "gen_res/Llama-3.1-8B-Instruct/contriever/numdoc_8_answerless_True/2025-08-31-11/gold_at0_answerless_info_12.pkl"
with open(path_1, "rb") as f:
    gen_result_1 = pickle.load(f)
with open(path_2, "rb") as f:
    gen_result_2 = pickle.load(f)

# %%
gen_result_1[0]['query'][:3]
# Out:
# ['who got the first nobel prize in physics',
#  'when is the next deadpool movie being released',
#  'the south west wind blows across nigeria between']

# %%
for a1, a2 in zip(gen_result_1[0]["generated_answer"][:8], gen_result_2[0]["generated_answer"]):
    print("A1:", a1)
    print("A2:", a2)
    print("-------")
# Out:
# A1: Wilhelm Conrad Röntgen, of Germany, who received 150,
# A2: Wilhelm Conrad Röntgen, of Germany, who received 150,
# -------
# A1: NO-RES. The answer cannot be extracted from any of the provided documents
# A2: NO-RES. The documents do not provide information about the release date of
# -------
# A1:
# A2: NO-RES. The documents do not provide information about the southwest wind blowing
# -------
# A1: NO-RES. The term "HP" appears in multiple contexts, including
# A2: NO-RES. The documents do not provide information on the meaning of "
# -------
# A1: NO-RES (None of the documents contain the answer) . However,
# A2: NO-RES (None of the documents contain the answer) . The documents
# -------
# A1: NO-RES. The answer cannot be extracted from any of the provided documents
# A2: Dai Yongge and Dai Xiuli (majority) NO-RES.
# -------
# A1: NO-RES. There is no information about the last time the Philadelphia Eagles
# A2: NO-RES (None of the documents contain the answer) or provide the
# ...

# %%
from datasets import load_dataset

load_dataset()
